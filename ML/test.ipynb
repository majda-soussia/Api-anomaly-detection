# %%
import pandas as pd

df = pd.read_csv("../data/X_raw.csv")
print(df.iloc[0].to_dict())
# Out:
# {'request_count': 1.0, 'unique_ips': 1.0, 'avg_response_time': 153.0, 'median_response_time': 153.0, 'p95_response_time': 153.0, 'p99_response_time': 153.0, 'max_response_time': 153.0, 'std_response_time': 0.0, 'error_rate_5xx': 0.0, 'error_rate_4xx': 0.0, 'success_rate': 1.0, 'avg_bytes_sent': 2256.0, 'total_bytes_sent': 2256.0, 'bot_ratio': 1.0, 'mobile_ratio': 0.0, 'desktop_ratio': 0.0, 'api_ratio': 1.0, 'static_ratio': 0.0, 'auth_ratio': 0.0, 'get_ratio': 1.0, 'post_ratio': 0.0, 'hour': 0.0, 'is_weekend': 0.0, 'is_business_hours': 0.0, 'response_time_change': 0.0, 'request_count_change': 0.0, 'error_rate_change': 0.0, 'rolling_avg_response': 153.0, 'response_vs_rolling': 0.0, 'stress_score': 153.0, 'quality_degradation': 151.4851485148515, 'latency_spike': 0.0, 'error_severity_ratio': 0.0, 'response_cv': 0.0, 'load_pressure': 153.0, 'log_avg_response': 5.0369526024136295, 'log_p99_response': 5.0369526024136295, 'log_std_response': 0.0, 'log_load_pressure': 5.0369526024136295, 're
# ...

# %%
import pandas as pd
import json

df = pd.read_csv("../data/X_raw.csv")

row = df.iloc[0].to_dict()

print(json.dumps(row, indent=2))
# Out:
# {
#   "request_count": 1.0,
#   "unique_ips": 1.0,
#   "avg_response_time": 153.0,
#   "median_response_time": 153.0,
#   "p95_response_time": 153.0,
#   "p99_response_time": 153.0,
#   "max_response_time": 153.0,
#   "std_response_time": 0.0,
#   "error_rate_5xx": 0.0,
#   "error_rate_4xx": 0.0,
#   "success_rate": 1.0,
#   "avg_bytes_sent": 2256.0,
#   "total_bytes_sent": 2256.0,
#   "bot_ratio": 1.0,
#   "mobile_ratio": 0.0,
#   "desktop_ratio": 0.0,
#   "api_ratio": 1.0,
#   "static_ratio": 0.0,
#   "auth_ratio": 0.0,
#   "get_ratio": 1.0,
#   "post_ratio": 0.0,
#   "hour": 0.0,
#   "is_weekend": 0.0,
#   "is_business_hours": 0.0,
#   "response_time_change": 0.0,
#   "request_count_change": 0.0,
#   "error_rate_change": 0.0,
#   "rolling_avg_response": 153.0,
#   "response_vs_rolling": 0.0,
#   "stress_score": 153.0,
#   "quality_degradation": 151.4851485148515,
#   "latency_spike": 0.0,
#   "error_severity_ratio": 0.0,
#   "response_cv": 0.0,
#   "load_pressure": 153.0,
# ...

# %%
df.tail(5)
# Out:
#       request_count  unique_ips  avg_response_time  median_response_time  \
# 4438            1.0         1.0               86.0                  86.0
# 4439            1.0         1.0               79.0                  79.0
# 4440            1.0         1.0              228.0                 228.0
# 4441            1.0         1.0              543.0                 543.0
# 4442            1.0         1.0              171.0                 171.0
#
#       p95_response_time  p99_response_time  max_response_time  \
# 4438               86.0               86.0               86.0
# 4439               79.0               79.0               79.0
# 4440              228.0              228.0              228.0
# 4441              543.0              543.0              543.0
# 4442              171.0              171.0              171.0
#
#       std_response_time  error_rate_5xx  error_rate_4xx  ...  \
# 4438                0.0             0.0             0.0  ...
# ...

# %%
df.sample(5)
# Out:
#       request_count  unique_ips  avg_response_time  median_response_time  \
# 2455            1.0         1.0               51.0                  51.0
# 221             1.0         1.0              116.0                 116.0
# 1561            1.0         1.0              232.0                 232.0
# 4039            2.0         2.0               47.0                  47.0
# 3701            1.0         1.0              112.0                 112.0
#
#       p95_response_time  p99_response_time  max_response_time  \
# 2455               51.0              51.00               51.0
# 221               116.0             116.00              116.0
# 1561              232.0             232.00              232.0
# 4039               47.9              47.98               48.0
# 3701              112.0             112.00              112.0
#
#       std_response_time  error_rate_5xx  error_rate_4xx  ...  \
# 2455           0.000000             0.0             0.0  ...
# ...
