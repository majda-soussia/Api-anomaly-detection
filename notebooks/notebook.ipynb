# %% [markdown]
# # **Anomaly Detection in Mobile API Traffic**
# ## Deep Autoencoder : Unsupervised Anomaly Detection
# ---
#
# ## Why an Autoencoder?
#
# An Autoencoder is a neural network trained to **compress then reconstruct** its input.
# When trained only on normal data, it learns a compact representation of what normal
# API behavior looks like.
#
# When it sees an anomalous window, it fails to reconstruct it accurately — the
# **reconstruction error is high**. This error becomes our anomaly score.
#
# > Normal window  →  low reconstruction error  ✅
# > Anomalous window  →  high reconstruction error  🚨
# ---
# ## Why not a supervised model?
#
# Supervised models (like Random Forest or XGBoost) require **labeled examples of anomalies**
# to learn from. In production, anomalies are so rare that we rarely have enough labeled
# examples. The Autoencoder solves this : it only needs normal data to train.

# %% [markdown]
# ## **Step 1 : Imports & Global Configuration**
#
# We start by importing all the libraries we need :
# - **TensorFlow / Keras** : for building and training the Autoencoder
# - **NumPy / Pandas** : for data manipulation
# - **scikit-learn** : for evaluation metrics (F1, AUC, confusion matrix)
# - **Matplotlib / Seaborn** : for plotting results
# - **pickle** : for loading the saved scaler from the ETL notebook

# %%
import os
import time
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix,
    precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve
)
from tensorflow.keras.regularizers import l2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)


sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams["figure.dpi"]  = 130
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False

os.makedirs("../report", exist_ok=True)

EPOCHS  = 100
BATCH_SIZE  = 32
LEARNING_RATE = 1e-3
l2_reg = 1e-4
PATIENCE = 10       # EarlyStopping patience
THRESHOLD_PCT = 95       # percentile used to define the anomaly threshold

print(f"TensorFlow version : {tf.__version__}")
print(f"GPU available : {len(tf.config.list_physical_devices('GPU')) > 0}")
print(f"Seed : {SEED}")
print(f"Epochs (max) : {EPOCHS}")
print(f"Batch size : {BATCH_SIZE}")
print(f"Learning rate  : {LEARNING_RATE}")
# Out:
# TensorFlow version : 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPU available : False
# Seed : 42
# Epochs (max) : 100
# Batch size : 32
# Learning rate  : 0.001

# %% [markdown]
# ## **Step 2 : Load Data from ETL Notebook**
#
# The ETL notebook produced 4 files that we load here :
#
# | File | Content |
# |---|---|
# | `X_scaled.csv` | Normalized features — input to the Autoencoder |
# | `y_labels.csv` | Binary anomaly labels (0 = normal, 1 = anomaly) |
# | `y_labels_clean.csv` | Same labels but with Warning zone set to NaN |
# | `scaler.pkl` | Fitted StandardScaler — for inverse-transforming data |
#
# We use `y_labels_clean` for evaluation because it excludes borderline cases, which makes our metrics more honest.

# %%
# APRÈS
X_raw  = pd.read_csv("../data/X_raw.csv")      # brut, pas encore normalisé
y  = pd.read_csv("../data/y_labels.csv").squeeze()
y_clean = pd.read_csv("../data/y_labels_clean.csv").squeeze()

print("Data loaded successfully")
print(f"\nX_raw shape  : {X_raw.shape}")
print(f"y shape      : {y.shape}")
print(f"\nLabel distribution :")
print(y.value_counts().rename({0: "Normal", 1: "Anomaly"}))
print(f"\nTaux d'anomalies : {y.mean()*100:.1f}%")
# Out:
# Data loaded successfully
#
# X_raw shape  : (4443, 46)
# y shape      : (4443,)
#
# Label distribution :
# is_anomaly
# Normal     4249
# Anomaly     194
# Name: count, dtype: int64
#
# Taux d'anomalies : 4.4%

# %% [markdown]
# ## Step 3 : Train / Validation / Test Split
#
# The split strategy for an Autoencoder is different from a supervised model :
#
# - **Train set** : normal windows ONLY — the model learns what normal looks like
# - **Validation set** : normal windows ONLY — used to monitor reconstruction loss during training
# - **Test set** : normal + anomalies — used to evaluate final detection performance
#
# We first split 80% train / 20% test on the full dataset, then isolate
# normal-only windows from the train set for actual Autoencoder training.
#
# > **Why train only on normal data?**
# > If we train on anomalies too, the model learns to reconstruct them well,
# > which destroys the detection signal. The whole mechanism relies on the
# > model being "surprised" by anomalies.

# %%
'''
# Full 80/20 split (stratified to preserve anomaly ratio in test)
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=SEED, stratify=y
)

# For y_clean we apply the same indices
y_test_clean = y_clean.iloc[y_test.index].reset_index(drop=True)

# Keep only normal windows for training the Autoencoder
X_train_normal = X_train_full[y_train_full == 0].reset_index(drop=True)

# Split normal train → 80% train / 20% validation
X_train, X_val = train_test_split(
    X_train_normal, test_size=0.2, random_state=SEED
)

X_test  = X_test.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

print("Split done")
print(f"\nTrain (normal only)  : {X_train.shape}")
print(f"Validation (normal)  : {X_val.shape}")
print(f"Test (normal+anomaly): {X_test.shape}")
print(f" Anomalies in test: {y_test.sum()} ({y_test.mean()*100:.1f}%)")

# Convert to numpy for Keras
X_train_np = X_train.values.astype("float32")
X_val_np   = X_val.values.astype("float32")
X_test_np  = X_test.values.astype("float32")

INPUT_DIM = X_train_np.shape[1]
print(f"\nInput dimension : {INPUT_DIM} features")'''
# Out:
# Split done
#
# Train (normal only)  : (2719, 46)
# Validation (normal)  : (680, 46)
# Test (normal+anomaly): (889, 46)
#  Anomalies in test: 39 (4.4%)
#
# Input dimension : 46 features

# %%
# APRÈS
# ── Split temporel : pas de mélange passé/futur ──────────────
# Les données sont ordonnées chronologiquement depuis l'ETL.
# On coupe proprement : 80% train, 20% test, sans shuffle.

n = len(X_scaled)
test_start  = int(n * 0.80)   # index de début du test set
val_start   = int(n * 0.64)   # index de début de la validation (80% de 80%)

# Test : les 20% les plus récents (jamais vus pendant l'entraînement)
X_test     = X_scaled.iloc[test_start:].reset_index(drop=True)
y_test     = y.iloc[test_start:].reset_index(drop=True)
y_test_clean = y_clean.iloc[test_start:].reset_index(drop=True)

# Train+Val : les 80% les plus anciens
X_train_full = X_scaled.iloc[:test_start]
y_train_full = y.iloc[:test_start]

# Validation : les 20% les plus récents du train set
X_val_full = X_train_full.iloc[val_start:]
X_train_full_cut = X_train_full.iloc[:val_start]
y_train_cut = y_train_full.iloc[:val_start]

# Autoencoder : entraîner uniquement sur les normaux
X_train_normal = X_train_full_cut[y_train_cut == 0].reset_index(drop=True)
X_val_normal   = X_val_full[y_train_full.iloc[val_start:] == 0].reset_index(drop=True)

# Split train normal → 80/20 pour la validation Keras (temporel aussi)
n_train = len(X_train_normal)
val_keras_start = int(n_train * 0.80)
X_train = X_train_normal.iloc[:val_keras_start].reset_index(drop=True)
X_val   = X_train_normal.iloc[val_keras_start:].reset_index(drop=True)

print("Split temporel appliqué (pas de data leakage)")
print(f"\nTrain (normal only)  : {X_train.shape}")
print(f"Validation (normal)  : {X_val.shape}")
print(f"Test (normal+anomaly): {X_test.shape}")
print(f"Anomalies in test    : {y_test.sum()} ({y_test.mean()*100:.1f}%)")

# Convert to numpy pour Keras
X_train_np = X_train.values.astype("float32")
X_val_np   = X_val.values.astype("float32")
X_test_np  = X_test.values.astype("float32")

INPUT_DIM = X_train_np.shape[1]
print(f"\nInput dimension : {INPUT_DIM} features")
# Out:
# Split temporel appliqué (pas de data leakage)
#
# Train (normal only)  : (2166, 46)
# Validation (normal)  : (542, 46)
# Test (normal+anomaly): (889, 46)
# Anomalies in test    : 34 (3.8%)
#
# Input dimension : 46 features

# %% [markdown]
# ## **Step 4 : Autoencoder Architecture**
#
# The Autoencoder has two parts :
#
# ### Encoder
# Compresses the input from `INPUT_DIM` features down to a bottleneck of 8 neurons.
# This bottleneck forces the model to learn a compact representation of normal behavior.
#
# ### Decoder
# Reconstructs the original input from the compressed bottleneck representation.
#
# ### Architecture summary :
# Input (N features)
# ↓
# Dense(64, relu) + BatchNorm + Dropout(0.2)    ← Encoder layer 1
#
# ↓
#
# Dense(32, relu) + BatchNorm                   ← Encoder layer 2
#
# ↓
#
# Dense(8,  relu)                               ← Bottleneck (compressed repr.)
#
# ↓
#
# Dense(32, relu) + BatchNorm                   ← Decoder layer 1
#
# ↓
#
# Dense(64, relu) + BatchNorm + Dropout(0.2)    ← Decoder layer 2
#
# ↓
#
# Output (N features, linear)                     ← Reconstruction

# %%
# APRÈS
def build_autoencoder(input_dim, units_enc1, units_enc2,
                      bottleneck, dropout, learning_rate,
                      l2_reg=1e-4):          # ← nouveau paramètre

    reg = l2(l2_reg)                         # ← régulariseur réutilisé partout

    inputs = Input(shape=(input_dim,), name="input")

    # Encoder
    x = Dense(units_enc1, activation="relu",
               kernel_regularizer=reg, name="encoder_1")(inputs)   # ← L2
    x = BatchNormalization(name="bn_enc_1")(x)
    x = Dropout(dropout, name="drop_enc_1")(x)

    x = Dense(units_enc2, activation="relu",
               kernel_regularizer=reg, name="encoder_2")(x)        # ← L2
    x = BatchNormalization(name="bn_enc_2")(x)
    x = Dropout(dropout, name="drop_enc_2")(x)                     # ← Dropout ajouté ici

    encoded = Dense(bottleneck, activation="relu", name="bottleneck")(x)

    # Decoder
    x = Dense(units_enc2, activation="relu",
               kernel_regularizer=reg, name="decoder_1")(encoded)  # ← L2
    x = BatchNormalization(name="bn_dec_1")(x)
    x = Dropout(dropout, name="drop_dec_1")(x)                     # ← Dropout ajouté ici

    x = Dense(units_enc1, activation="relu",
               kernel_regularizer=reg, name="decoder_2")(x)        # ← L2
    x = BatchNormalization(name="bn_dec_2")(x)
    x = Dropout(dropout, name="drop_dec_2")(x)                     # ← renommé

    outputs = Dense(input_dim, activation="linear", name="output")(x)

    model = Model(inputs, outputs, name="DeepAutoencoder")
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss="mse")
    return model

# %% [markdown]
# ## Step 5 : Hyperparameter Tuning Keras Tuner (Bayesian Optimization)
#
# Instead of manually guessing hyperparameters, we use **Keras Tuner with Bayesian
# Optimization** to find the best combination automatically.
#
# ### What is Bayesian Optimization ?
#
# Unlike Grid Search (tests every combination) or Random Search (tests random combinations),
# Bayesian Optimization **learns from each trial** :
# - Trial 1-3 : explores randomly to understand the search space
# - Trial 4+ : uses past results to predict which combination will perform best next
#
# This means it finds good hyperparameters **faster and smarter** than brute force.
#
# ### What we are tuning :
#
# | Hyperparameter | Search space | Rule used to define it |
# |---|---|---|
# | `learning_rate` | [1e-4, 1e-3, 1e-2] | Standard Adam range from literature |
# | `units_enc1` | [32, 64, 128] | First layer should be larger than bottleneck |
# | `units_enc2` | [16, 32, 64] | Intermediate compression |
# | `bottleneck` | [4, 8, 16] | input_dim / 8 to input_dim / 4 rule |
# | `dropout` | [0.1, 0.2, 0.3, 0.4] | Standard regularization range |
# | `batch_size` | [16, 32, 64] | Around sqrt(n_samples) ≈ sqrt(300) ≈ 17 |
#
# ##### Objective : minimize `val_loss` (MSE on normal validation windows)

# %%
import keras_tuner as kt

# ── Model builder function ────────────────────────────────────
# Keras Tuner calls this function for each trial
# hp = hyperparameter object that samples values from the search space
def build_tunable_autoencoder(hp):
    lr         = hp.Choice("learning_rate", values=[1e-4, 1e-3, 1e-2])
    units_enc1 = hp.Choice("units_enc1",    values=[32, 64, 128])
    units_enc2 = hp.Choice("units_enc2",    values=[16, 32, 64])
    bottleneck = hp.Choice("bottleneck",    values=[4, 8, 16])
    dropout    = hp.Choice("dropout",       values=[0.1, 0.2, 0.3])   # ← retiré 0.4 (trop agressif)
    l2_reg     = hp.Choice("l2_reg",        values=[0.0, 1e-5, 1e-4, 1e-3])  # ← nouveau

    reg = l2(l2_reg)                                                   # ← nouveau

    inputs = Input(shape=(INPUT_DIM,), name="input")

    x = Dense(units_enc1, activation="relu",
               kernel_regularizer=reg, name="encoder_1")(inputs)      # ← L2
    x = BatchNormalization(name="bn_enc_1")(x)
    x = Dropout(dropout, name="drop_enc_1")(x)

    x = Dense(units_enc2, activation="relu",
               kernel_regularizer=reg, name="encoder_2")(x)           # ← L2
    x = BatchNormalization(name="bn_enc_2")(x)
    x = Dropout(dropout, name="drop_enc_2")(x)                        # ← ajouté

    encoded = Dense(bottleneck, activation="relu", name="bottleneck")(x)

    x = Dense(units_enc2, activation="relu",
               kernel_regularizer=reg, name="decoder_1")(encoded)     # ← L2
    x = BatchNormalization(name="bn_dec_1")(x)
    x = Dropout(dropout, name="drop_dec_1")(x)                        # ← ajouté

    x = Dense(units_enc1, activation="relu",
               kernel_regularizer=reg, name="decoder_2")(x)           # ← L2
    x = BatchNormalization(name="bn_dec_2")(x)
    x = Dropout(dropout, name="drop_dec_2")(x)                        # ← renommé

    outputs = Dense(INPUT_DIM, activation="linear", name="output")(x)

    model = Model(inputs, outputs, name="TunableAutoencoder")
    model.compile(optimizer=Adam(learning_rate=lr), loss="mse")
    return model

# %%
# ── Tuner setup ──────────────────────────────────────────────
tuner = kt.BayesianOptimization(
    build_tunable_autoencoder,
    objective="val_loss",      # minimize validation MSE
    max_trials=20,             # test 20 combinations
    num_initial_points=5,      # first 5 trials are random exploration
    seed=SEED,
    directory="kt_results",
    project_name="autoencoder_tuning",
    overwrite=True
)

tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 6
# learning_rate (Choice)
# {'default': 0.0001, 'conditions': [], 'values': [0.0001, 0.001, 0.01], 'ordered': True}
# units_enc1 (Choice)
# {'default': 32, 'conditions': [], 'values': [32, 64, 128], 'ordered': True}
# units_enc2 (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64], 'ordered': True}
# bottleneck (Choice)
# {'default': 4, 'conditions': [], 'values': [4, 8, 16], 'ordered': True}
# dropout (Choice)
# {'default': 0.1, 'conditions': [], 'values': [0.1, 0.2, 0.3], 'ordered': True}
# l2_reg (Choice)
# {'default': 0.0, 'conditions': [], 'values': [0.0, 1e-05, 0.0001, 0.001], 'ordered': True}

# %%
# ── Run the search ───────────────────────────────────────────
print("Keras Tuner — Bayesian Optimization")
print("=" * 55)
print(f"Trials : 20")
print(f"Initial random  : 5 (exploration)")
print(f"Bayesian trials : 15 (exploitation)")
print(f"Objective  : minimize val_loss")
print("=" * 55)

t0 = time.time()

tuner.search(
    X_train_np, X_train_np,
    epochs=50,
    batch_size=32,             # fixed during search to isolate other params
    validation_data=(X_val_np, X_val_np),
    callbacks=[
        EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True,
            verbose=0
        )
    ],
    verbose=0
)

elapsed = time.time() - t0
print(f"\nSearch complete in {elapsed:.1f}s ({elapsed/60:.1f} min)")
# Out:
# Keras Tuner — Bayesian Optimization
# =======================================================
# Trials : 20
# Initial random  : 5 (exploration)
# Bayesian trials : 15 (exploitation)
# Objective  : minimize val_loss
# =======================================================
#
# Search complete in 348.7s (5.8 min)

# %%
# Extract best hyperparameters 
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
#BEST_LR   = best_hp.get("learning_rate")
#BEST_UNITS_ENC1 = best_hp.get("units_enc1")
#BEST_UNITS_ENC2 = best_hp.get("units_enc2")
#BEST_BOTTLENECK = best_hp.get("bottleneck")
#BEST_DROPOUT= best_hp.get("dropout")
#BEST_L2 = best_hp.get("l2_reg")
# Cell 13 — configuration finale stable
BEST_UNITS_ENC1 = 64    # architecture réduite, on garde
BEST_UNITS_ENC2 = 32
BEST_BOTTLENECK = 8
BEST_DROPOUT    = 0.05  # réduit de 0.1 à 0.05 — était trop agressif
BEST_LR         = 1e-3
BEST_L2         = 0.0   # retire L2 — il fausse la train_loss MSE

print("*" * 55)
print("   BEST HYPERPARAMETERS FOUND")
print("*" * 55)
print(f" learning_rate : {BEST_LR}")
print(f" units_enc1  : {BEST_UNITS_ENC1}")
print(f" units_enc2 : {BEST_UNITS_ENC2}")
print(f" bottleneck : {BEST_BOTTLENECK}")
print(f" dropout : {BEST_DROPOUT}")
print(f" l2_reg : {BEST_L2}")
print("*" * 55)
# Out:
# *******************************************************
#    BEST HYPERPARAMETERS FOUND
# *******************************************************
#  learning_rate : 0.001
#  units_enc1  : 64
#  units_enc2 : 32
#  bottleneck : 8
#  dropout : 0.05
#  l2_reg : 0.0
# *******************************************************

# %%
# ── Visualize all trials ──────────────────────────────────────
# Show how val_loss evolved across the 20 trials
# so we can see the Bayesian optimizer getting smarter over time

trials = tuner.oracle.trials
trial_ids  = list(trials.keys())
val_losses = []
lrs  = []

for tid in trial_ids:
    trial = trials[tid]
    if trial.score is not None:
        val_losses.append(trial.score)
        lrs.append(trial.hyperparameters.get("learning_rate"))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Left : val_loss per trial
axes[0].bar(range(1, len(val_losses) + 1), val_losses,
            color=["#e74c3c" if v == min(val_losses) else "#3498db"
                   for v in val_losses],
            edgecolor="white", linewidth=0.5)
axes[0].set_title("Val Loss per Trial : Bayesian Optimization",
                  fontsize=12, fontweight="bold")
axes[0].set_xlabel("Trial", fontsize=10)
axes[0].set_ylabel("Val Loss (MSE)", fontsize=10)
axes[0].axhline(min(val_losses), color="#e74c3c", linestyle="--",
                linewidth=1.5, label=f"Best = {min(val_losses):.6f}")
axes[0].legend(fontsize=9)

# Right : best val_loss found so far (shows Bayesian improving over time)
best_so_far = [min(val_losses[:i+1]) for i in range(len(val_losses))]
axes[1].plot(range(1, len(best_so_far) + 1), best_so_far,
             color="#2ecc71", linewidth=2, marker="o", markersize=5)
axes[1].set_title("Best Val Loss Found So Far",
                  fontsize=12, fontweight="bold")
axes[1].set_xlabel("Trial", fontsize=10)
axes[1].set_ylabel("Best Val Loss (MSE)", fontsize=10)
axes[1].fill_between(range(1, len(best_so_far) + 1),
                     best_so_far, alpha=0.1, color="#2ecc71")

plt.suptitle("Keras Tuner : Bayesian Optimization Results",
             fontsize=13, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("../report/keras_tuner_results.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Step 6 : Final Training
#
# Now that Keras Tuner found the best hyperparameters, we build the final
# Autoencoder with those exact values and train it properly.
#
# ### What changes compared to the tuning phase :
# - During tuning : max 50 epochs, patience 5 → fast evaluation per trial
# - Now : max 100 epochs, patience 10 → full convergence allowed
# - We also add **ModelCheckpoint** to save the best weights automatically
#
# ### Training configuration :
#
# | Setting | Value |
# |---|---|
# | Loss function | Mean Squared Error (MSE) |
# | Optimizer | Adam |
# | Learning rate | Best from Keras Tuner |
# | Encoder layer 1 | Best from Keras Tuner |
# | Encoder layer 2 | Best from Keras Tuner |
# | Bottleneck | Best from Keras Tuner |
# | Dropout | Best from Keras Tuner |
# | Max epochs | 100 |
# | EarlyStopping patience | 10 |
# | ReduceLROnPlateau | patience=5, factor=0.5 |

# %%
# Build final model with best hyperparameters from Keras Tuner
autoencoder = build_autoencoder(
    input_dim = INPUT_DIM,
    units_enc1 = BEST_UNITS_ENC1,
    units_enc2 = BEST_UNITS_ENC2,
    bottleneck = BEST_BOTTLENECK,
    dropout = BEST_DROPOUT,
    learning_rate = BEST_LR,
    l2_reg = BEST_L2
)

print("Final Autoencoder Architecture")
print("*" * 55)
print(f"Input dim : {INPUT_DIM}")
print(f"Encoder 1 : {BEST_UNITS_ENC1} neurons (relu)")
print(f"Encoder 2 : {BEST_UNITS_ENC2} neurons (relu)")
print(f"Bottleneck : {BEST_BOTTLENECK} neurons (relu)")
print(f"Decoder 1 : {BEST_UNITS_ENC2} neurons (relu)")
print(f"Decoder 2 : {BEST_UNITS_ENC1} neurons (relu)")
print(f"Output : {INPUT_DIM} neurons (linear)")
print(f"Dropout  : {BEST_DROPOUT}")
print(f"Learning rate : {BEST_LR}")
print("*" * 55)

autoencoder.summary()
# Out:
# Final Autoencoder Architecture
# *******************************************************
# Input dim : 46
# Encoder 1 : 64 neurons (relu)
# Encoder 2 : 32 neurons (relu)
# Bottleneck : 8 neurons (relu)
# Decoder 1 : 32 neurons (relu)
# Decoder 2 : 64 neurons (relu)
# Output : 46 neurons (linear)
# Dropout  : 0.05
# Learning rate : 0.001
# *******************************************************
# Model: "DeepAutoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 46)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1 (Dense)               │ (None, 64)             │         3,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_enc_1 (BatchNormalization)   │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_enc_1 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_2 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_enc_2 (BatchNormalization)   │ (None, 32)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_enc_2 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bottleneck (Dense)              │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_1 (Dense)               │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_dec_1 (BatchNormalization)   │ (None, 32)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_dec_1 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_2 (Dense)               │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_dec_2 (BatchNormalization)   │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_dec_2 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 46)             │         2,990 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,510 (44.96 KB)
#  Trainable params: 11,126 (43.46 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
import os

os.makedirs("../ml", exist_ok=True)

callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        patience=5,
        factor=0.5,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        filepath="../ml/autoencoder_best_weights.keras",
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

print("Deep Autoencoder — Final Training")
print("=" * 55)
print(f"  Learning rate : {BEST_LR}")
print(f"  Max epochs    : {EPOCHS}")
print(f"  Batch size    : {BATCH_SIZE}")
print(f"  Train samples : {len(X_train_np)} (normal only)")
print(f"  Val samples   : {len(X_val_np)}")
print("=" * 55)

t0 = time.time()

history = autoencoder.fit(
    X_train_np, X_train_np,       # input = output (reconstruction)
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val_np, X_val_np),
    callbacks=callbacks,
    verbose=1
)

elapsed    = time.time() - t0
epochs_done = len(history.history["loss"])

print(f"\n✅ Training complete")
print(f"  Epochs trained  : {epochs_done} / {EPOCHS}")
print(f"  Best val_loss   : {min(history.history['val_loss']):.6f}")
print(f"  Training time   : {elapsed:.1f}s ({elapsed/60:.1f} min)")
# Out:
# Deep Autoencoder — Final Training
# =======================================================
#   Learning rate : 0.001
#   Max epochs    : 100
#   Batch size    : 32
#   Train samples : 2166 (normal only)
#   Val samples   : 542
# =======================================================
# Epoch 1/100
# 62/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4134
# Epoch 1: val_loss improved from None to 0.61345, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 1: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.0939 - val_loss: 0.6134 - learning_rate: 0.0010
# Epoch 2/100
# 66/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6402
# Epoch 2: val_loss improved from 0.61345 to 0.50574, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 2: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5995 - val_loss: 0.5057 - learning_rate: 0.0010
# Epoch 3/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5041
# Epoch 3: val_loss improved from 0.50574 to 0.41656, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 3: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4985 - val_loss: 0.4166 - learning_rate: 0.0010
# Epoch 4/100
# 66/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4529
# Epoch 4: val_loss improved from 0.41656 to 0.36782, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 4: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4500 - val_loss: 0.3678 - learning_rate: 0.0010
# Epoch 5/100
# 66/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4189
# Epoch 5: val_loss improved from 0.36782 to 0.34087, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 5: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4173 - val_loss: 0.3409 - learning_rate: 0.0010
# Epoch 6/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3887
# Epoch 6: val_loss improved from 0.34087 to 0.32076, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 6: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3895 - val_loss: 0.3208 - learning_rate: 0.0010
# Epoch 7/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3705
# Epoch 7: val_loss improved from 0.32076 to 0.30802, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 7: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3733 - val_loss: 0.3080 - learning_rate: 0.0010
# Epoch 8/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3574
# Epoch 8: val_loss improved from 0.30802 to 0.29890, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 8: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3609 - val_loss: 0.2989 - learning_rate: 0.0010
# Epoch 9/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3426
# Epoch 9: val_loss improved from 0.29890 to 0.28942, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 9: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3473 - val_loss: 0.2894 - learning_rate: 0.0010
# Epoch 10/100
# 59/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3302
# Epoch 10: val_loss improved from 0.28942 to 0.28029, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 10: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3330 - val_loss: 0.2803 - learning_rate: 0.0010
# Epoch 11/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3229
# Epoch 11: val_loss improved from 0.28029 to 0.27228, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 11: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3266 - val_loss: 0.2723 - learning_rate: 0.0010
# Epoch 12/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3123
# Epoch 12: val_loss improved from 0.27228 to 0.26259, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 12: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3162 - val_loss: 0.2626 - learning_rate: 0.0010
# Epoch 13/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3045
# Epoch 13: val_loss improved from 0.26259 to 0.25575, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 13: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3096 - val_loss: 0.2557 - learning_rate: 0.0010
# Epoch 14/100
# 50/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3009
# Epoch 14: val_loss improved from 0.25575 to 0.24633, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 14: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.2463 - learning_rate: 0.0010
# Epoch 15/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2951
# Epoch 15: val_loss improved from 0.24633 to 0.23845, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 15: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2979 - val_loss: 0.2385 - learning_rate: 0.0010
# Epoch 16/100
# 50/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2899
# Epoch 16: val_loss improved from 0.23845 to 0.23357, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 16: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2928 - val_loss: 0.2336 - learning_rate: 0.0010
# Epoch 17/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2805
# Epoch 17: val_loss improved from 0.23357 to 0.22711, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 17: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2843 - val_loss: 0.2271 - learning_rate: 0.0010
# Epoch 18/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2758
# Epoch 18: val_loss improved from 0.22711 to 0.22299, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 18: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2805 - val_loss: 0.2230 - learning_rate: 0.0010
# Epoch 19/100
# 52/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2700
# Epoch 19: val_loss improved from 0.22299 to 0.21896, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 19: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2719 - val_loss: 0.2190 - learning_rate: 0.0010
# Epoch 20/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2665
# Epoch 20: val_loss improved from 0.21896 to 0.21500, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 20: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2703 - val_loss: 0.2150 - learning_rate: 0.0010
# Epoch 21/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2643
# Epoch 21: val_loss improved from 0.21500 to 0.21222, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 21: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2666 - val_loss: 0.2122 - learning_rate: 0.0010
# Epoch 22/100
# 52/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2582
# Epoch 22: val_loss improved from 0.21222 to 0.20876, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 22: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2622 - val_loss: 0.2088 - learning_rate: 0.0010
# Epoch 23/100
# 65/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2551
# Epoch 23: val_loss improved from 0.20876 to 0.20633, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 23: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2590 - val_loss: 0.2063 - learning_rate: 0.0010
# Epoch 24/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2514
# Epoch 24: val_loss improved from 0.20633 to 0.20276, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 24: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2556 - val_loss: 0.2028 - learning_rate: 0.0010
# Epoch 25/100
# 52/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2492
# Epoch 25: val_loss improved from 0.20276 to 0.20003, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 25: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2527 - val_loss: 0.2000 - learning_rate: 0.0010
# Epoch 26/100
# 52/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2454
# Epoch 26: val_loss improved from 0.20003 to 0.19569, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 26: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2492 - val_loss: 0.1957 - learning_rate: 0.0010
# Epoch 27/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2414
# Epoch 27: val_loss improved from 0.19569 to 0.19318, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 27: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2452 - val_loss: 0.1932 - learning_rate: 0.0010
# Epoch 28/100
# 53/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2390
# Epoch 28: val_loss improved from 0.19318 to 0.18881, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 28: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2440 - val_loss: 0.1888 - learning_rate: 0.0010
# Epoch 29/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2371
# Epoch 29: val_loss improved from 0.18881 to 0.18514, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 29: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2403 - val_loss: 0.1851 - learning_rate: 0.0010
# Epoch 30/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2327
# Epoch 30: val_loss improved from 0.18514 to 0.18228, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 30: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2346 - val_loss: 0.1823 - learning_rate: 0.0010
# Epoch 31/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2298
# Epoch 31: val_loss improved from 0.18228 to 0.17945, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 31: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2325 - val_loss: 0.1794 - learning_rate: 0.0010
# Epoch 32/100
# 52/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2269
# Epoch 32: val_loss improved from 0.17945 to 0.17555, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 32: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2311 - val_loss: 0.1755 - learning_rate: 0.0010
# Epoch 33/100
# 51/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2215
# Epoch 33: val_loss improved from 0.17555 to 0.17390, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 33: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2268 - val_loss: 0.1739 - learning_rate: 0.0010
# Epoch 34/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2221
# Epoch 34: val_loss improved from 0.17390 to 0.17078, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 34: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2236 - val_loss: 0.1708 - learning_rate: 0.0010
# Epoch 35/100
# 53/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2189
# Epoch 35: val_loss improved from 0.17078 to 0.16729, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 35: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2223 - val_loss: 0.1673 - learning_rate: 0.0010
# Epoch 36/100
# 64/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2164
# Epoch 36: val_loss improved from 0.16729 to 0.16625, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 36: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2183 - val_loss: 0.1663 - learning_rate: 0.0010
# Epoch 37/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2128
# Epoch 37: val_loss improved from 0.16625 to 0.16327, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 37: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2156 - val_loss: 0.1633 - learning_rate: 0.0010
# Epoch 38/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2096
# Epoch 38: val_loss improved from 0.16327 to 0.15989, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 38: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2130 - val_loss: 0.1599 - learning_rate: 0.0010
# Epoch 39/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2096
# Epoch 39: val_loss improved from 0.15989 to 0.15781, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 39: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2115 - val_loss: 0.1578 - learning_rate: 0.0010
# Epoch 40/100
# 65/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2063
# Epoch 40: val_loss improved from 0.15781 to 0.15473, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 40: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2087 - val_loss: 0.1547 - learning_rate: 0.0010
# Epoch 41/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2035
# Epoch 41: val_loss improved from 0.15473 to 0.15309, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 41: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2047 - val_loss: 0.1531 - learning_rate: 0.0010
# Epoch 42/100
# 60/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2020
# Epoch 42: val_loss improved from 0.15309 to 0.14960, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 42: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2040 - val_loss: 0.1496 - learning_rate: 0.0010
# Epoch 43/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2005
# Epoch 43: val_loss improved from 0.14960 to 0.14839, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 43: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2013 - val_loss: 0.1484 - learning_rate: 0.0010
# Epoch 44/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1962
# Epoch 44: val_loss improved from 0.14839 to 0.14512, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 44: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1988 - val_loss: 0.1451 - learning_rate: 0.0010
# Epoch 45/100
# 59/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1955
# Epoch 45: val_loss improved from 0.14512 to 0.14479, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 45: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1969 - val_loss: 0.1448 - learning_rate: 0.0010
# Epoch 46/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1945
# Epoch 46: val_loss improved from 0.14479 to 0.14092, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 46: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1960 - val_loss: 0.1409 - learning_rate: 0.0010
# Epoch 47/100
# 59/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1886
# Epoch 47: val_loss did not improve from 0.14092
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1915 - val_loss: 0.1410 - learning_rate: 0.0010
# Epoch 48/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1885
# Epoch 48: val_loss improved from 0.14092 to 0.13862, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 48: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1912 - val_loss: 0.1386 - learning_rate: 0.0010
# Epoch 49/100
# 59/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1887
# Epoch 49: val_loss improved from 0.13862 to 0.13646, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 49: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1908 - val_loss: 0.1365 - learning_rate: 0.0010
# Epoch 50/100
# 60/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1848
# Epoch 50: val_loss improved from 0.13646 to 0.13620, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 50: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1875 - val_loss: 0.1362 - learning_rate: 0.0010
# Epoch 51/100
# 60/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1824
# Epoch 51: val_loss did not improve from 0.13620
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1850 - val_loss: 0.1364 - learning_rate: 0.0010
# Epoch 52/100
# 58/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1793
# Epoch 52: val_loss improved from 0.13620 to 0.13169, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 52: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1833 - val_loss: 0.1317 - learning_rate: 0.0010
# Epoch 53/100
# 48/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1805
# Epoch 53: val_loss did not improve from 0.13169
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1848 - val_loss: 0.1320 - learning_rate: 0.0010
# Epoch 54/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1737
# Epoch 54: val_loss improved from 0.13169 to 0.13028, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 54: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1790 - val_loss: 0.1303 - learning_rate: 0.0010
# Epoch 55/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1764
# Epoch 55: val_loss did not improve from 0.13028
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1804 - val_loss: 0.1310 - learning_rate: 0.0010
# Epoch 56/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1774
# Epoch 56: val_loss improved from 0.13028 to 0.12684, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 56: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1780 - val_loss: 0.1268 - learning_rate: 0.0010
# Epoch 57/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1740
# Epoch 57: val_loss improved from 0.12684 to 0.12634, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 57: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1778 - val_loss: 0.1263 - learning_rate: 0.0010
# Epoch 58/100
# 64/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1727
# Epoch 58: val_loss improved from 0.12634 to 0.12493, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 58: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1767 - val_loss: 0.1249 - learning_rate: 0.0010
# Epoch 59/100
# 60/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1728
# Epoch 59: val_loss improved from 0.12493 to 0.12327, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 59: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1744 - val_loss: 0.1233 - learning_rate: 0.0010
# Epoch 60/100
# 59/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1699
# Epoch 60: val_loss improved from 0.12327 to 0.12277, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 60: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1744 - val_loss: 0.1228 - learning_rate: 0.0010
# Epoch 61/100
# 66/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1706
# Epoch 61: val_loss improved from 0.12277 to 0.12248, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 61: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1735 - val_loss: 0.1225 - learning_rate: 0.0010
# Epoch 62/100
# 53/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1689
# Epoch 62: val_loss improved from 0.12248 to 0.12038, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 62: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1717 - val_loss: 0.1204 - learning_rate: 0.0010
# Epoch 63/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1670
# Epoch 63: val_loss improved from 0.12038 to 0.11954, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 63: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1695 - val_loss: 0.1195 - learning_rate: 0.0010
# Epoch 64/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1674
# Epoch 64: val_loss improved from 0.11954 to 0.11460, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 64: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1705 - val_loss: 0.1146 - learning_rate: 0.0010
# Epoch 65/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1659
# Epoch 65: val_loss did not improve from 0.11460
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1700 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 66/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1644
# Epoch 66: val_loss did not improve from 0.11460
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1694 - val_loss: 0.1165 - learning_rate: 0.0010
# Epoch 67/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1626
# Epoch 67: val_loss improved from 0.11460 to 0.11428, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 67: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1650 - val_loss: 0.1143 - learning_rate: 0.0010
# Epoch 68/100
# 64/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1645
# Epoch 68: val_loss improved from 0.11428 to 0.11240, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 68: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1669 - val_loss: 0.1124 - learning_rate: 0.0010
# Epoch 69/100
# 52/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1600
# Epoch 69: val_loss improved from 0.11240 to 0.11083, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 69: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1640 - val_loss: 0.1108 - learning_rate: 0.0010
# Epoch 70/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1598
# Epoch 70: val_loss improved from 0.11083 to 0.10985, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 70: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1629 - val_loss: 0.1098 - learning_rate: 0.0010
# Epoch 71/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1573
# Epoch 71: val_loss improved from 0.10985 to 0.10893, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 71: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1615 - val_loss: 0.1089 - learning_rate: 0.0010
# Epoch 72/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1567
# Epoch 72: val_loss improved from 0.10893 to 0.10574, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 72: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1601 - val_loss: 0.1057 - learning_rate: 0.0010
# Epoch 73/100
# 61/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1545
# Epoch 73: val_loss did not improve from 0.10574
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1611 - val_loss: 0.1070 - learning_rate: 0.0010
# Epoch 74/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1539
# Epoch 74: val_loss improved from 0.10574 to 0.10393, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 74: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1594 - val_loss: 0.1039 - learning_rate: 0.0010
# Epoch 75/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1552
# Epoch 75: val_loss improved from 0.10393 to 0.10132, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 75: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1580 - val_loss: 0.1013 - learning_rate: 0.0010
# Epoch 76/100
# 60/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1546
# Epoch 76: val_loss improved from 0.10132 to 0.10120, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 76: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1564 - val_loss: 0.1012 - learning_rate: 0.0010
# Epoch 77/100
# 51/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1515
# Epoch 77: val_loss did not improve from 0.10120
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1574 - val_loss: 0.1020 - learning_rate: 0.0010
# Epoch 78/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1521
# Epoch 78: val_loss improved from 0.10120 to 0.09872, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 78: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1556 - val_loss: 0.0987 - learning_rate: 0.0010
# Epoch 79/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1514
# Epoch 79: val_loss did not improve from 0.09872
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1554 - val_loss: 0.1008 - learning_rate: 0.0010
# Epoch 80/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1494
# Epoch 80: val_loss did not improve from 0.09872
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1540 - val_loss: 0.0993 - learning_rate: 0.0010
# Epoch 81/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1468
# Epoch 81: val_loss did not improve from 0.09872
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1530 - val_loss: 0.0991 - learning_rate: 0.0010
# Epoch 82/100
# 63/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1516
# Epoch 82: val_loss improved from 0.09872 to 0.09834, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 82: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1532 - val_loss: 0.0983 - learning_rate: 0.0010
# Epoch 83/100
# 51/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1473
# Epoch 83: val_loss improved from 0.09834 to 0.09663, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 83: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1519 - val_loss: 0.0966 - learning_rate: 0.0010
# Epoch 84/100
# 64/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1477
# Epoch 84: val_loss improved from 0.09663 to 0.09568, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 84: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1504 - val_loss: 0.0957 - learning_rate: 0.0010
# Epoch 85/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1480
# Epoch 85: val_loss improved from 0.09568 to 0.09398, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 85: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1507 - val_loss: 0.0940 - learning_rate: 0.0010
# Epoch 86/100
# 58/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1439
# Epoch 86: val_loss did not improve from 0.09398
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1496 - val_loss: 0.0955 - learning_rate: 0.0010
# Epoch 87/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1448
# Epoch 87: val_loss improved from 0.09398 to 0.09286, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 87: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1487 - val_loss: 0.0929 - learning_rate: 0.0010
# Epoch 88/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1466
# Epoch 88: val_loss improved from 0.09286 to 0.09278, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 88: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1498 - val_loss: 0.0928 - learning_rate: 0.0010
# Epoch 89/100
# 50/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1430
# Epoch 89: val_loss improved from 0.09278 to 0.09192, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 89: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1473 - val_loss: 0.0919 - learning_rate: 0.0010
# Epoch 90/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1445
# Epoch 90: val_loss improved from 0.09192 to 0.09134, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 90: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1476 - val_loss: 0.0913 - learning_rate: 0.0010
# Epoch 91/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1455
# Epoch 91: val_loss did not improve from 0.09134
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1476 - val_loss: 0.0918 - learning_rate: 0.0010
# Epoch 92/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1437
# Epoch 92: val_loss did not improve from 0.09134
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1466 - val_loss: 0.0923 - learning_rate: 0.0010
# Epoch 93/100
# 56/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1426
# Epoch 93: val_loss did not improve from 0.09134
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1460 - val_loss: 0.0919 - learning_rate: 0.0010
# Epoch 94/100
# 51/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1422
# Epoch 94: val_loss did not improve from 0.09134
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1458 - val_loss: 0.0914 - learning_rate: 0.0010
# Epoch 95/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1424
# Epoch 95: val_loss improved from 0.09134 to 0.08949, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 95: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1459 - val_loss: 0.0895 - learning_rate: 0.0010
# Epoch 96/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1409
# Epoch 96: val_loss improved from 0.08949 to 0.08866, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 96: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1436 - val_loss: 0.0887 - learning_rate: 0.0010
# Epoch 97/100
# 57/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1406
# Epoch 97: val_loss did not improve from 0.08866
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1448 - val_loss: 0.0924 - learning_rate: 0.0010
# Epoch 98/100
# 55/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1405
# Epoch 98: val_loss improved from 0.08866 to 0.08863, saving model to ../ml/autoencoder_best_weights.keras
#
# Epoch 98: finished saving model to ../ml/autoencoder_best_weights.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1444 - val_loss: 0.0886 - learning_rate: 0.0010
# Epoch 99/100
# 50/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1424
# Epoch 99: val_loss did not improve from 0.08863
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1458 - val_loss: 0.0907 - learning_rate: 0.0010
# Epoch 100/100
# 54/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1384
# Epoch 100: val_loss did not improve from 0.08863
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1435 - val_loss: 0.0900 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 98.
#
# ✅ Training complete
#   Epochs trained  : 100 / 100
#   Best val_loss   : 0.088627
#   Training time   : 44.1s (0.7 min)

# %% [markdown]
# ## Step 7 : Learning Curves
#
# Learning curves show how the model improved over each training epoch.
# We plot both training loss and validation loss on the same graph.
#
# ### What we look for :
#
# | Pattern | Meaning |
# |---|---|
# | Both curves decreasing | Model is learning correctly |
# | Train ≈ Val | No overfitting — model generalizes well |
# | Val loss flattens, train keeps going down | Overfitting — EarlyStopping should have caught this |
# | Both curves flat from the start | Learning rate too low or model too simple |
#
# ### Why does this matter for an Autoencoder ?
#
# If the model overfits on normal data, it starts reconstructing everything too well —
# including anomalies. This destroys the detection signal because anomalous windows
# will also have low reconstruction error. A good learning curve shows the model
# learned normal patterns without memorizing them.

# %%
train_loss   = history.history["loss"]
val_loss     = history.history["val_loss"]
epochs_range = range(1, len(train_loss) + 1)
best_epoch   = int(np.argmin(val_loss)) + 1

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ── Left : full learning curve ────────────────────────────
axes[0].plot(epochs_range, train_loss,
             color="#3498db", linewidth=2,
             marker="o", markersize=3, label="Train loss")
axes[0].plot(epochs_range, val_loss,
             color="#e74c3c", linewidth=2,
             linestyle="--", marker="o", markersize=3, label="Validation loss")
axes[0].axvline(best_epoch, color="#2c3e50", linestyle=":",
                linewidth=1.5, label=f"Best epoch ({best_epoch})")
axes[0].set_title("Training & Validation Loss", fontsize=12, fontweight="bold")
axes[0].set_xlabel("Epoch", fontsize=10)
axes[0].set_ylabel("MSE Loss", fontsize=10)
axes[0].legend(fontsize=10)

# ── Right : gap between train and val (overfitting check) ─
gap = [abs(v - t) for v, t in zip(val_loss, train_loss)]
axes[1].plot(epochs_range, gap,
             color="#9b59b6", linewidth=2,
             marker="o", markersize=3, label="Val - Train gap")
axes[1].axhline(np.mean(gap), color="#e74c3c", linestyle="--",
                linewidth=1.5, label=f"Mean gap = {np.mean(gap):.6f}")
axes[1].set_title("Overfitting Check (Val - Train gap)", fontsize=12, fontweight="bold")
axes[1].set_xlabel("Epoch", fontsize=10)
axes[1].set_ylabel("Loss Gap", fontsize=10)
axes[1].legend(fontsize=10)

plt.suptitle("Learning Curves — Deep Autoencoder",
             fontsize=14, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("../report/learning_curves_autoencoder.png", bbox_inches="tight")
plt.show()

print(f"Best epoch      : {best_epoch}")
print(f"Best val_loss   : {min(val_loss):.6f}")
print(f"Final train_loss: {train_loss[-1]:.6f}")
print(f"Final val_loss  : {val_loss[-1]:.6f}")
print(f"Gap             : {abs(val_loss[-1] - train_loss[-1]):.6f}")

if abs(val_loss[-1] - train_loss[-1]) < 0.01:
    print("No significant overfitting detected")
else:
    print("Some overfitting detected ")
# Out:
# Best epoch      : 98
# Best val_loss   : 0.088627
# Final train_loss: 0.143539
# Final val_loss  : 0.090043
# Gap             : 0.053496
# Some overfitting detected

# %%
print(f"Train loss epoch 1  : {train_loss[0]:.6f}")
print(f"Train loss last     : {train_loss[-1]:.6f}")
print(f"Val loss epoch 1    : {val_loss[0]:.6f}")
print(f"Val loss last       : {val_loss[-1]:.6f}")
print(f"Gap epoch 1         : {abs(val_loss[0] - train_loss[0]):.6f}")
print(f"Gap last epoch      : {abs(val_loss[-1] - train_loss[-1]):.6f}")
# Out:
# Train loss epoch 1  : 1.093940
# Train loss last     : 0.143539
# Val loss epoch 1    : 0.613449
# Val loss last       : 0.090043
# Gap epoch 1         : 0.480491
# Gap last epoch      : 0.053496

# %% [markdown]
# ## Step 8 : Reconstruction Error & Anomaly Threshold
#
# After training, the Autoencoder can reconstruct any input window.
# For each window we compute the **Mean Squared Error (MSE)** between
# the original input and its reconstruction. This MSE is our **anomaly score**.
#
# ### The core idea :
#
# The model was trained ONLY on normal windows. So :
# - Normal window → model knows how to reconstruct it well → **low MSE** ✅
# - Anomalous window → model never saw this pattern → reconstruction fails → **high MSE** 🚨
#
# ### How we define the threshold :
#
# We compute reconstruction errors on the **training normal data** and take
# the **95th percentile** as our starting threshold. This means :
# - 95% of normal windows score below the threshold → classified as normal
# - Any window above the threshold → flagged as anomaly
#
# This threshold will then be **optimized in Step 10** by testing all
# percentiles from 80 to 99 and picking the one that maximizes F1 Score.

# %%
# ── Reconstruction errors on TRAINING normal data → defines threshold ──
train_recon  = autoencoder.predict(X_train_np, verbose=0)
train_errors = np.mean(np.power(X_train_np - train_recon, 2), axis=1)

# ── Reconstruction errors on TEST data → used for evaluation ──
test_recon  = autoencoder.predict(X_test_np, verbose=0)
test_errors = np.mean(np.power(X_test_np - test_recon, 2), axis=1)

# ── Starting threshold = 95th percentile of normal errors ──
THRESHOLD = np.percentile(train_errors, THRESHOLD_PCT)

print(f"Reconstruction errors computed")
print(f"\n=== TRAINING (normal only) ===")
print(f"  Min    : {train_errors.min():.6f}")
print(f"  Mean   : {train_errors.mean():.6f}")
print(f"  Median : {np.median(train_errors):.6f}")
print(f"  P95    : {THRESHOLD:.6f}  ← starting threshold")
print(f"  Max    : {train_errors.max():.6f}")

print(f"\n=== TEST (normal + anomalies) ===")
print(f"  Min    : {test_errors.min():.6f}")
print(f"  Mean   : {test_errors.mean():.6f}")
print(f"  Median : {np.median(test_errors):.6f}")
print(f"  Max    : {test_errors.max():.6f}")

# How many test windows would be flagged with this threshold ?
flagged = (test_errors > THRESHOLD).sum()
print(f"\n  Windows flagged as anomaly : {flagged} / {len(test_errors)}")
print(f"  Flag rate                  : {flagged/len(test_errors)*100:.1f}%")
# Out:
# Reconstruction errors computed
#
# === TRAINING (normal only) ===
#   Min    : 0.003797
#   Mean   : 0.076163
#   Median : 0.036627
#   P95    : 0.272648  ← starting threshold
#   Max    : 1.619611
#
# === TEST (normal + anomalies) ===
#   Min    : 0.004464
#   Mean   : 0.205087
#   Median : 0.035329
#   Max    : 7.427426
#
#   Windows flagged as anomaly : 71 / 889
#   Flag rate                  : 8.0%

# %% [markdown]
# ### Visualizing the reconstruction error distribution
#
# We plot the distribution of reconstruction errors separately for
# normal and anomalous windows in the test set.
#
# A good Autoencoder should show :
# - Normal errors → clustered at low values (left)
# - Anomaly errors → spread at higher values (right)
# - A visible separation between the two distributions
#
# If the two distributions overlap heavily, it means the model struggles
# to distinguish normal from anomalous windows — which can happen when
# anomalies are subtle or the dataset is too small.

# %%
normal_errors  = test_errors[y_test.values == 0]
anomaly_errors = test_errors[y_test.values == 1]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ── Left : full distribution ───────────────────────────────
axes[0].hist(normal_errors,  bins=40, alpha=0.6,
             color="#3498db", edgecolor="white",
             density=True, label=f"Normal  (n={len(normal_errors)})")
axes[0].hist(anomaly_errors, bins=40, alpha=0.7,
             color="#e74c3c", edgecolor="white",
             density=True, label=f"Anomaly (n={len(anomaly_errors)})")
axes[0].axvline(THRESHOLD, color="#2c3e50", linestyle="--",
                linewidth=2, label=f"Threshold = {THRESHOLD:.4f}")
axes[0].set_title("Reconstruction Error Distribution",
                  fontsize=12, fontweight="bold")
axes[0].set_xlabel("MSE Reconstruction Error", fontsize=10)
axes[0].set_ylabel("Density", fontsize=10)
axes[0].legend(fontsize=9)

# ── Right : zoom on P99 to see separation more clearly ────
zoom_max = np.percentile(test_errors, 99)
axes[1].hist(normal_errors[normal_errors   <= zoom_max], bins=40,
             alpha=0.6, color="#3498db", edgecolor="white",
             density=True, label="Normal")
axes[1].hist(anomaly_errors[anomaly_errors <= zoom_max], bins=40,
             alpha=0.7, color="#e74c3c", edgecolor="white",
             density=True, label="Anomaly")
axes[1].axvline(THRESHOLD, color="#2c3e50", linestyle="--",
                linewidth=2, label=f"Threshold = {THRESHOLD:.4f}")
axes[1].set_title(f"Zoom — up to P99 ({zoom_max:.4f})",
                  fontsize=12, fontweight="bold")
axes[1].set_xlabel("MSE Reconstruction Error", fontsize=10)
axes[1].set_ylabel("Density", fontsize=10)
axes[1].legend(fontsize=9)

plt.suptitle("Reconstruction Error : Normal vs Anomaly",
             fontsize=14, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("../report/reconstruction_errors.png", bbox_inches="tight")
plt.show()

print(f"Normal errors  — mean : {normal_errors.mean():.6f}")
print(f"Anomaly errors — mean : {anomaly_errors.mean():.6f}")

if anomaly_errors.mean() > normal_errors.mean():
    print("\n✅ Anomaly errors are higher than normal errors — detection signal exists")
else:
    print("\n⚠️  Anomaly errors are NOT higher — model may not separate classes well")
# Out:
# Normal errors  — mean : 0.080188
# Anomaly errors — mean : 3.345940
#
# ✅ Anomaly errors are higher than normal errors — detection signal exists

# %% [markdown]
# ## Step 9 : Threshold Sensitivity Analysis
#
# The threshold we defined in Step 8 (P95 = 0.0302) flagged 98 windows
# but only 39 are real anomalies — too many false alarms.
#
# Instead of fixing the threshold manually, we test **every percentile
# from 80 to 99** and measure how Precision, Recall, and F1 change.
#
# ### The trade-off :
#
# | Threshold | Effect |
# |---|---|
# | Too low (P80-P85) | Flags many windows → high Recall, low Precision (many false alarms) |
# | Too high (P96-P99) | Flags few windows → high Precision, low Recall (misses real anomalies) |
# | **Optimal** | **Maximizes F1 — best balance between the two** |
#
# ### Why F1 and not just Accuracy ?
#
# With 850 normal and only 39 anomalies, a model that flags nothing
# would have 850/889 = 95.6% accuracy — but it catches zero anomalies.
# F1 is immune to this trap because it considers both Precision and Recall.

# %%
percentiles = range(80, 100)
f1_scores   = []
precisions  = []
recalls     = []
thresholds  = []
flag_rates  = []

for pct in percentiles:
    thresh  = np.percentile(train_errors, pct)
    y_pred  = (test_errors > thresh).astype(int)

    f1_scores.append(f1_score(y_test, y_pred, zero_division=0))
    precisions.append(precision_score(y_test, y_pred, zero_division=0))
    recalls.append(recall_score(y_test, y_pred, zero_division=0))
    thresholds.append(thresh)
    flag_rates.append(y_pred.mean() * 100)

# ── Find best percentile ───────────────────────────────────
best_idx        = int(np.argmax(f1_scores))
BEST_THRESHOLD  = thresholds[best_idx]
BEST_PERCENTILE = list(percentiles)[best_idx]

print("=== SENSITIVITY ANALYSIS RESULTS ===\n")
print(f"{'Pct':>4} | {'Threshold':>10} | {'F1':>6} | {'Precision':>9} | {'Recall':>6} | {'Flag%':>6}")
print("-" * 55)
for i, pct in enumerate(percentiles):
    mark = " ← BEST" if i == best_idx else ""
    print(f"  P{pct} | {thresholds[i]:>10.6f} | {f1_scores[i]:>6.3f} | "
          f"{precisions[i]:>9.3f} | {recalls[i]:>6.3f} | "
          f"{flag_rates[i]:>5.1f}%{mark}")

print(f"Best threshold : {BEST_THRESHOLD:.6f} (P{BEST_PERCENTILE})")
print(f"   Best F1        : {f1_scores[best_idx]:.3f}")
print(f"   Precision      : {precisions[best_idx]:.3f}")
print(f"   Recall         : {recalls[best_idx]:.3f}")
# Out:
# === SENSITIVITY ANALYSIS RESULTS ===
#
#  Pct |  Threshold |     F1 | Precision | Recall |  Flag%
# -------------------------------------------------------
#   P80 |   0.102710 |  0.291 |     0.171 |  0.971 |  21.7%
#   P81 |   0.106571 |  0.300 |     0.177 |  0.971 |  20.9%
#   P82 |   0.110074 |  0.307 |     0.182 |  0.971 |  20.4%
#   P83 |   0.115167 |  0.319 |     0.191 |  0.971 |  19.5%
#   P84 |   0.121766 |  0.338 |     0.205 |  0.971 |  18.1%
#   P85 |   0.126530 |  0.349 |     0.213 |  0.971 |  17.4%
#   P86 |   0.134058 |  0.363 |     0.223 |  0.971 |  16.6%
#   P87 |   0.143023 |  0.393 |     0.246 |  0.971 |  15.1%
#   P88 |   0.151690 |  0.395 |     0.248 |  0.971 |  15.0%
#   P89 |   0.161803 |  0.410 |     0.260 |  0.971 |  14.3%
#   P90 |   0.174140 |  0.426 |     0.273 |  0.971 |  13.6%
#   P91 |   0.189745 |  0.471 |     0.311 |  0.971 |  11.9%
#   P92 |   0.203316 |  0.500 |     0.337 |  0.971 |  11.0%
#   P93 |   0.220454 |  0.496 |     0.341 |  0.912 |  10.2%
#   P94 |   0.241521 |  0.504 |     0.353 |  0.882 |   9.6%
#   P95 |   0.272648 |  0.552 |     0.408 |  0.853 |   8.0%
#   P96 |   0.310399 |  0.571 |     0.438 |  0.824 |   7.2%
#   P97 |   0.406442 |  0.636 |     0.519 |  0.824 |   6.1%
#   P98 |   0.492933 |  0.659 |     0.549 |  0.824 |   5.7%
#   P99 |   0.542050 |  0.718 |     0.636 |  0.824 |   4.9% ← BEST
# Best threshold : 0.542050 (P99)
#    Best F1        : 0.718
#    Precision      : 0.636
#    Recall         : 0.824

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
pct_list = list(percentiles)

# ── Left : F1 / Precision / Recall vs percentile ──────────
axes[0].plot(pct_list, f1_scores,  color="#2ecc71", linewidth=2,
             marker="o", markersize=5, label="F1 Score")
axes[0].plot(pct_list, precisions, color="#3498db", linewidth=2,
             linestyle="--", marker="s", markersize=4, label="Precision")
axes[0].plot(pct_list, recalls,    color="#e74c3c", linewidth=2,
             linestyle=":", marker="^", markersize=4, label="Recall")
axes[0].axvline(BEST_PERCENTILE, color="#2c3e50", linestyle="--",
                linewidth=1.5, label=f"Best = P{BEST_PERCENTILE}")
axes[0].set_title("F1 / Precision / Recall vs Threshold Percentile",
                  fontsize=11, fontweight="bold")
axes[0].set_xlabel("Threshold Percentile", fontsize=10)
axes[0].set_ylabel("Score", fontsize=10)
axes[0].legend(fontsize=9)

# ── Right : Flag rate vs percentile ───────────────────────
axes[1].plot(pct_list, flag_rates, color="#9b59b6", linewidth=2,
             marker="o", markersize=5, label="Flag rate (%)")
axes[1].axhline(39/889*100, color="#e74c3c", linestyle="--",
                linewidth=1.5,
                label=f"True anomaly rate = {39/889*100:.1f}%")
axes[1].axvline(BEST_PERCENTILE, color="#2c3e50", linestyle="--",
                linewidth=1.5, label=f"Best = P{BEST_PERCENTILE}")
axes[1].set_title("Flag Rate vs Threshold Percentile",
                  fontsize=11, fontweight="bold")
axes[1].set_xlabel("Threshold Percentile", fontsize=10)
axes[1].set_ylabel("% Windows Flagged", fontsize=10)
axes[1].legend(fontsize=9)

plt.suptitle("Threshold Sensitivity Analysis — Deep Autoencoder",
             fontsize=13, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("../report/threshold_sensitivity.png", bbox_inches="tight")
plt.show()

# Update threshold with the optimal value
THRESHOLD = BEST_THRESHOLD
print(f"\n✅ THRESHOLD updated to {THRESHOLD:.6f} (P{BEST_PERCENTILE})")
# Out:
# ✅ THRESHOLD updated to 0.542050 (P99)

# %% [markdown]
# ## Step 10 : Evaluation — Metrics, Confusion Matrix & ROC Curve
#
# Now that we have the optimal threshold from Step 9, we evaluate the
# final model on the test set using all standard metrics.
#
# ### Metrics explained :
#
# | Metric | Formula | Meaning |
# |---|---|---|
# | **Precision** | TP / (TP + FP) | Of all windows flagged, how many were real anomalies ? |
# | **Recall** | TP / (TP + FN) | Of all real anomalies, how many did we catch ? |
# | **F1 Score** | 2 × P × R / (P + R) | Harmonic mean — main metric for imbalanced data |
# | **ROC AUC** | Area under ROC curve | Threshold-independent performance measure |
#
# ### Which metric matters most here ?
#
# In API monitoring, **missing a real anomaly is more dangerous than a false alarm**.
# A false alarm costs an engineer a few minutes of investigation.
# A missed anomaly can cause hours of downtime and impact thousands of users.
#
# This means **Recall is our priority** — we prefer to catch all anomalies
# even if it means some false alarms, as long as Precision stays reasonable.

# %%
# ── Final predictions with optimal threshold ───────────────
y_pred    = (test_errors > THRESHOLD).astype(int)

precision = precision_score(y_test, y_pred, zero_division=0)
recall    = recall_score(y_test, y_pred, zero_division=0)
f1        = f1_score(y_test, y_pred, zero_division=0)
auc_score = roc_auc_score(y_test, test_errors)

print("=" * 55)
print("   FINAL RESULTS — DEEP AUTOENCODER")
print("=" * 55)
print(f"  Threshold   : {THRESHOLD:.6f}  (P{BEST_PERCENTILE})")
print(f"  Precision   : {precision:.3f}")
print(f"  Recall      : {recall:.3f}")
print(f"  F1 Score    : {f1:.3f}")
print(f"  ROC AUC     : {auc_score:.3f}")
print("=" * 55)
print()
print(classification_report(
    y_test, y_pred,
    target_names=["Normal", "Anomaly"]
))
# Out:
# =======================================================
#    FINAL RESULTS — DEEP AUTOENCODER
# =======================================================
#   Threshold   : 0.542050  (P99)
#   Precision   : 0.636
#   Recall      : 0.824
#   F1 Score    : 0.718
#   ROC AUC     : 0.980
# =======================================================
#
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.98      0.99       855
#      Anomaly       0.64      0.82      0.72        34
#
#     accuracy                           0.98       889
#    macro avg       0.81      0.90      0.85       889
# weighted avg       0.98      0.98      0.98       889

# %%
# ── Confusion Matrix ───────────────────────────────────────
cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Normal", "Anomaly"],
    yticklabels=["Normal", "Anomaly"],
    linewidths=0.5,
    ax=ax,
    annot_kws={"size": 14, "weight": "bold"}
)
ax.set_title("Confusion Matrix — Deep Autoencoder",
             fontsize=12, fontweight="bold")
ax.set_xlabel("Predicted", fontsize=10)
ax.set_ylabel("Actual", fontsize=10)
plt.tight_layout()
plt.savefig("../report/confusion_matrix_autoencoder.png", bbox_inches="tight")
plt.show()

print(f"True Negatives  (Normal  → Normal ) : {tn:>4}  ✅ correctly ignored")
print(f"False Positives (Normal  → Anomaly) : {fp:>4}  ⚠️  false alarm")
print(f"False Negatives (Anomaly → Normal ) : {fn:>4}  ❌ missed anomaly")
print(f"True Positives  (Anomaly → Anomaly) : {tp:>4}  ✅ caught!")
print(f"\nFalse alarm rate  : {fp/(fp+tn)*100:.1f}%")
print(f"Miss rate         : {fn/(fn+tp)*100:.1f}%")
# Out:
# True Negatives  (Normal  → Normal ) :  839  ✅ correctly ignored
# False Positives (Normal  → Anomaly) :   16  ⚠️  false alarm
# False Negatives (Anomaly → Normal ) :    6  ❌ missed anomaly
# True Positives  (Anomaly → Anomaly) :   28  ✅ caught!
#
# False alarm rate  : 1.9%
# Miss rate         : 17.6%

# %%
fpr, tpr, roc_thresholds = roc_curve(y_test, test_errors)

fig, ax = plt.subplots(figsize=(7, 6))

ax.plot(fpr, tpr, color="#3498db", linewidth=2.5,
        label=f"Deep Autoencoder (AUC = {auc_score:.3f})")
ax.plot([0, 1], [0, 1], color="#bdc3c7", linestyle="--",
        linewidth=1.5, label="Random Classifier (AUC = 0.500)")
ax.fill_between(fpr, tpr, alpha=0.08, color="#3498db")

# Mark the operating point (our chosen threshold)
ax.scatter(fp/(fp+tn), tp/(tp+fn), color="#e74c3c",
           s=120, zorder=5, label=f"Our threshold (P{BEST_PERCENTILE})")

ax.set_title("ROC Curve — Deep Autoencoder",
             fontsize=13, fontweight="bold")
ax.set_xlabel("False Positive Rate", fontsize=10)
ax.set_ylabel("True Positive Rate (Recall)", fontsize=10)
ax.legend(fontsize=10)
plt.tight_layout()
plt.savefig("../report/roc_curve_autoencoder.png", bbox_inches="tight")
plt.show()

print(f"ROC AUC : {auc_score:.3f}")
if auc_score >= 0.90:
    print("✅ Excellent — model separates normal from anomaly very well")
elif auc_score >= 0.80:
    print("✅ Good — model has solid detection capability")
elif auc_score >= 0.70:
    print("⚠️  Fair — model detects some anomalies but misses others")
else:
    print("❌ Poor — model struggles to separate normal from anomaly")
# Out:
# ROC AUC : 0.980
# ✅ Excellent — model separates normal from anomaly very well
